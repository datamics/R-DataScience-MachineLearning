# %% [markdown]
# # Hilfe für R erhalten
#
# Neben einer Googlesuche und [StackOverflow](www.stackoverflow.com) gibt es einige in R eingebaute Möglichkeiten, um Hilfe zu erhalten!
#
# Die meisten R Funktionen haben eine Online Dokumentation:
#
# * help(thema) - Dokumentation zum Thema
# * help.search("thema") - Die Hilfe durchsuchen
# * apropos("thema") - Ergibt die Namen aller Objekte in der Suche, die "thema" entsprechen
# * help.start() - Startet die HTML Version der Hilfe
# * str(a) - Zeigt die interne *Str*uktur eine R Objekts an
# * summary(a) - Gibt eine Zusammenfassung. Für numerische Objekte ist es eine statistische. Für andere Onjekte gibt es andere Versionen
# * ls() - Zeigt Objekte im Suchpfad
# * ls.str() - Führt `str()` für jedes Objekt im Suchpfad aus
# * dir() - Zeigt die Dateien im aktuellen Verzeichnis
# * methods(a) - Zeigt die S3 Methoden für a
# * methods(class=class(a)) - Listet alle Methoden auf, die für ein Objekt der Klasse a verwendet werden können
#
# Schauen wir uns nun einige Beispiele an, wie wir diese Hilfe nutzen können. Wir gehen dabei allerdings nicht alle durch, da manche nicht sehr nützlich für uns sind. Noch nicht!

# %%
# Für Hilfe mit Vektoren
help(vector)
# Out:
# vector                  package:base                   R Documentation
#
# s
#
# n:
#
#      ‘vector’ produces a vector of the given length and mode.
#
#      ‘as.vector’, a generic, attempts to coerce its argument into a
#      vector of mode ‘mode’ (the default is to coerce to whichever
#      vector mode is most convenient): if the result is atomic all
#      attributes are removed.
#
#      ‘is.vector’ returns ‘TRUE’ if ‘x’ is a vector of the specified
#      mode having no attributes _other than names_.  It returns ‘FALSE’
#      otherwise.
#
# e:
#
#      vector(mode = "logical", length = 0)
#      as.vector(x, mode = "any")
#      is.vector(x, mode = "any")
#
# s:
#
#     mode: character string naming an atomic mode or ‘"list"’ or
#           ‘"expression"’ or (except for ‘vector’) ‘"any"’.
#
#   length: a non-negative integer specifying the desired length.  For a
#           long vector, i.e., ‘length > .Machine$integer.max’, it has to
# ...

# %% [markdown]
# Sehr gut! Wir können auch danach suchen.

# %%
# Das wird ein Fenster öffnen
help.search('numeric')

# %%
# Außerdem können wir ?? für eine Suche verwenden
??vector

# %%
# Für eine kleine statistische Zusammenfassung können wir summary verwenden
v <- c(1,2,3,4,5,6)
summary(v)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    1.00    2.25    3.50    3.50    4.75    6.00

# %% [markdown]
# Wir werden diese Tools später verwenden, um mehr Informationen zu erhalten. Zum jetzigen Zeitpunkt sollten wir uns `help()` und `??` in Erinnerung behalten.
