# %% [markdown]
# # Eingebaute R Features - Daten Strukturen
#
# R beinhaltet einige nützliche eingebaute Funktionen, um mit Datenstrukturen zu arbeiten. Hier sind einige der Hauptfunktionen, die wir lernen wollen:
#
# * seq(): Eine Sequenz erstellen
# * sort(): Einen Vektor sortieren
# * rev(): Elemente in einem Objekt umkehren
# * str(): Die Struktur eines Objekts anzeigen
# * append(): Objekte zusammenfügen (funktioniert mit Vektoren und Listen)

# %%
# seq(start,ende,schrittgröße)
seq(0, 100, by = 3)
# Out:
#  [1]  0  3  6  9 12 15 18 21 24 27 30 33 36 39 42 45 48 51 54 57 60 63 66 69 72
# [26] 75 78 81 84 87 90 93 96 99

# %%
v <- c(1,4,6,7,2,13,2)

# %%
sort(v)
# Out:
# [1]  1  2  2  4  6  7 13

# %%
sort(v,decreasing = TRUE)
# Out:
# [1] 13  7  6  4  2  2  1

# %%
v2 <- c(1,2,3,4,5)
rev(v2)
# Out:
# [1] 5 4 3 2 1

# %%
str(v)
# Out:
#  num [1:7] 1 4 6 7 2 13 2

# %%
append(v,v2)
# Out:
#  [1]  1  4  6  7  2 13  2  1  2  3  4  5

# %%
sort(append(v,v2))
# Out:
#  [1]  1  1  2  2  2  3  4  4  5  6  7 13

# %% [markdown]
# ### Daten Typen
#
# * is.*(): Die Klasse eine R Objekts überprüfen
# * as.*(): R Objekte konvertieren

# %%
v <- c(1,2,3)
is.vector(v)
# Out:
# [1] TRUE

# %%
is.list(v)
# Out:
# [1] FALSE

# %%
as.list(v)
# Out:
# [[1]]
# [1] 1
#
# [[2]]
# [1] 2
#
# [[3]]
# [1] 3

# %%
as.matrix(v)
# Out:
#      [,1]
# [1,] 1
# [2,] 2
# [3,] 3

# %% [markdown]
# Toll! Soviel zu den eingebauten Datenstrukturen Funtkionen! Diese gehen recht leicht von der Hand, versucht also sie euch für die Übung zu merken!
